# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshatpattiwar512/Letsupgrade-Advance-Data-Science/blob/main/ADV_DATA_SCIENCE_DAY_10_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###       Q1 Pandas Assignment

# %% [markdown]
# ###How to import pandas and check the version?

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# ### How to convert the index of a series into a column of a dataframe?

# %%
import pandas as pd 
  
  
df = pd.DataFrame({'Roll Number': ['20CSE29', '20CSE49', '20CSE36', '20CSE44'], 
                   'Name': ['Amelia', 'Sam', 'Dean', 'Jessica'], 
                   'Marks In Percentage': [97, 90, 70, 82], 
                   'Grade': ['A', 'A', 'C', 'B'], 
                   'Subject': ['Physics', 'Physics', 'Physics', 'Physics']}) 
  
# Printing the dataframe 
df['index'] = df.index 
df
# Out:
#   Roll Number     Name  Marks In Percentage Grade  Subject  index
# 0     20CSE29   Amelia                   97     A  Physics      0
# 1     20CSE49      Sam                   90     A  Physics      1
# 2     20CSE36     Dean                   70     C  Physics      2
# 3     20CSE44  Jessica                   82     B  Physics      3

# %% [markdown]
# ### How to combine many series to form a dataframe?

# %%
import pandas as pd 

def createSeries (series_list): 
  series_list = pd.Series(series_list) 
  return series_list 
  

students = createSeries(['ABC', 'DEF', 
                         'GHI', 'JKL', 
                         'MNO', 'PQR'])   

subject = createSeries(['C++', 'C#',  
                        'RUBY', 'SWIFT', 
                        'GO', 'PYTHON']) 
 
marks = createSeries([90, 30,  
                      50, 70,  
                      80, 60]) 

data = {"students": students, 
        "subject": subject, 
        "marks": marks} 

df = pd.concat(data, 
               axis = 1) 

df
# Out:
#   students subject  marks
# 0      ABC     C++     90
# 1      DEF      C#     30
# 2      GHI    RUBY     50
# 3      JKL   SWIFT     70
# 4      MNO      GO     80
# 5      PQR  PYTHON     60

# %% [markdown]
# ### How to assign a name to the series’ index?

# %%
import pandas as pd 
# Creating the Series 
sr = pd.Series([10, 25, 3, 11, 24, 6]) 
  
# Create the Index 
index_ = ['Coca Cola', 'Sprite', 'Coke', 'Fanta', 'Dew', 'ThumbsUp'] 
  
# set the index 
sr.index = index_ 
  
# Print the series 
print(sr)
# Out:
# Coca Cola    10
# Sprite       25
# Coke          3
# Fanta        11
# Dew          24
# ThumbsUp      6
# dtype: int64

# %% [markdown]
# ### How to get the minimum, 25th percentile, median, 75th, and max of a numeric series?

# %%
import pandas as pd
import numpy as np
num_state = np.random.RandomState(100)
num_series = pd.Series(num_state.normal(10, 4, 20))
print("Original Series:")
print(num_series)
result = np.percentile(num_series, q=[0, 25, 50, 75, 100])
print("\nMinimum, 25th percentile, median, 75th, and maximum of a given series:")
print(result)
# Out:
# Original Series:
# 0      3.000938
# 1     11.370722
# 2     14.612143
# 3      8.990256
# 4     13.925283
# 5     12.056875
# 6     10.884719
# 7      5.719827
# 8      9.242017
# 9     11.020006
# 10     8.167892
# 11    11.740654
# 12     7.665620
# 13    13.267388
# 14    12.690883
# 15     9.582355
# 16     7.874878
# 17    14.118931
# 18     8.247458
# 19     5.526727
# dtype: float64
#
# Minimum, 25th percentile, median, 75th, and maximum of a given series:
# [ 3.00093811  8.09463867 10.23353705 12.21537733 14.61214321]

# %% [markdown]
# ### What is qcut() in Pandas?

# %%
#The function defines the bins using percentiles based on the distribution of the data, not the actual numeric edges of the bins.

# %% [markdown]
# ### How to find the positions of numbers that are multiples of 3 from a series?

# %%
# input

np.random.RandomState(100)
ser = pd.Series(np.random.randint(1, 5, 10))
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# 4    1
# 5    3
# 6    3
# 7    2
# 8    3
# 9    2
# dtype: int64

# %% [markdown]
# ### How to stack two series vertically and horizontally ?

# %%
import pandas as pd 
  
# creating the series 
series1 = pd.Series(['g', 'e', 'e', 'k', 's']) 
print("Series 1:") 
print(series1) 
series2 = pd.Series([9, 8, 7, 6, 5]) 
print("Series 2:") 
print(series2) 
   
# stacking the series horizontally 
df = pd.concat([series1, series2], axis = 1) 
print("\nStack two series horizontally:") 
display(df) 
print("")
print('')
import pandas as pd 
  
# creating the series 
series1 = pd.Series(['g', 'e', 'e', 'k', 's']) 
print("Series 1:") 
print(series1) 
series2 = pd.Series([9, 8, 7, 6, 5]) 
print("Series 2:") 
print(series2) 
   
# stacking the series vertically 
df = pd.concat([series1, series2], axis = 0) 
print("\nStack two series vertically:") 
display(df)
# Out:
# Series 1:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object
# Series 2:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# dtype: int64
#
# Stack two series horizontally:
#    0  1
# 0  g  9
# 1  e  8
# 2  e  7
# 3  k  6
# 4  s  5
# Series 1:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object
# Series 2:
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# dtype: int64
#
# Stack two series vertically:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# 0    9
# 1    8
# 2    7
# 3    6
# 4    5
# dtype: object

# %% [markdown]
# ### How to get the day of month, week number, day of year and day of week from a series of date strings?

# %%
import pandas as pd
from dateutil.parser import parse
Series = pd.Series(['01 Jan 2015', '10-02-2016', '20180307', '2014/05/06', '2016-04-12', '2019-04-06T11:20'])
print("Original Series:")
print(Series)
Series = Series.map(lambda x: parse(x))
print("Day of month:")
print(Series.dt.day.tolist())
print("Day of year:")
print(Series.dt.dayofyear.tolist())
print("Week number:")
print(Series.dt.weekofyear.tolist())
print("Day of week:")
print(Series.dt.isocalendar().week)
# Out:
# Original Series:
# 0         01 Jan 2015
# 1          10-02-2016
# 2            20180307
# 3          2014/05/06
# 4          2016-04-12
# 5    2019-04-06T11:20
# dtype: object
# Day of month:
# [1, 2, 7, 6, 12, 6]
# Day of year:
# [1, 276, 66, 126, 103, 96]
# Week number:
# [1, 39, 10, 19, 15, 14]
# Day of week:
# 0     1
# 1    39
# 2    10
# 3    19
# 4    15
# 5    14
# Name: week, dtype: UInt32
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   if sys.path[0] == '':

# %% [markdown]
# ### How to compute the euclidean distance between two series?

# %%
import pandas as pd 
import numpy as np 
# create pandas series 
x = pd.Series([1, 2, 3, 4, 5]) 
y = pd.Series([6, 7, 8, 9, 10]) 
  
# here we are computing every thing 
# step by step 
p1 = np.sum([(a * a) for a in x]) 
p2 = np.sum([(b * b) for b in y]) 
  
# using zip() function to create an 
# iterator which aggregates elements  
# from two or more iterables 
p3 = -1 * np.sum([(2 * a*b) for (a, b) in zip(x, y)]) 
dist = np.sqrt(np.sum(p1 + p2 + p3)) 
  
print("Series 1:", x) 
print("Series 2:", y) 
print("Euclidean distance between two series is:", dist)
# Out:
# Series 1: 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# Series 2: 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64
# Euclidean distance between two series is: 11.180339887498949

# %% [markdown]
# ### How to use apply function on existing columns?

# %%
import pandas as pd
c=[{'a': 15, 'b': 15, 'c': 5}, {'a': 20, 'b': 10, 'c': 7}, {'a': 25, 'b': 30, 'c': 9}]
df = pd.DataFrame(c)
df.assign(a=lambda df: df.a / 2)

df
# Out:
#     a   b  c
# 0  15  15  5
# 1  20  10  7
# 2  25  30  9

# %% [markdown]
# ### Q2 Pandas Assignment

# %% [markdown]
# ### Use Pandas' read_csv function directly on this url to open it as a DataFrame

# %%
import pandas as pd
c = pd.read_csv("http://www.ldeo.columbia.edu/~rpa/usgs_earthquakes_2014.csv")
print(c)
# Out:
#                            time  ...        type
# 0       2014-01-31 23:53:37.000  ...  earthquake
# 1       2014-01-31 23:48:35.452  ...  earthquake
# 2       2014-01-31 23:47:24.000  ...  earthquake
# 3       2014-01-31 23:30:54.000  ...  earthquake
# 4       2014-01-31 23:30:52.210  ...  earthquake
# ...                         ...  ...         ...
# 120103  2014-12-01 00:10:16.000  ...  earthquake
# 120104  2014-12-01 00:09:39.000  ...  earthquake
# 120105  2014-12-01 00:09:25.350  ...  earthquake
# 120106  2014-12-01 00:05:54.000  ...  earthquake
# 120107  2014-12-01 00:04:05.000  ...  earthquake
#
# [120108 rows x 15 columns]

# %% [markdown]
# ### Use describe to get the basic statistics of all the columns.

# %%
desc = c.describe()
desc
# Out:
#             latitude      longitude  ...          dmin            rms
# count  120108.000000  120108.000000  ...  85682.000000  119716.000000
# mean       38.399579     -99.961402  ...      0.893198       0.358174
# std        21.938258      82.996858  ...      2.903966       0.364046
# min       -73.462000    -179.998900  ...      0.000000       0.000000
# 25%        34.228917    -147.742025  ...      0.020760       0.070000
# 50%        38.805300    -120.832000  ...      0.073670       0.200000
# 75%        53.889500    -116.068100  ...      0.447000       0.590000
# max        86.651400     179.998000  ...     64.498000       8.460000
#
# [8 rows x 8 columns]

# %% [markdown]
# ### Use sort_values to get the top 20 earthquakes by magnitude.

# %%
h=c.sort_values("mag",ascending=False)
g=h.head(20)
g
# Out:
#                            time  ...        type
# 37371   2014-04-01 23:46:47.260  ...  earthquake
# 50562   2014-06-23 20:53:09.700  ...  earthquake
# 36918   2014-04-03 02:43:13.110  ...  earthquake
# 33808   2014-04-12 20:14:39.300  ...  earthquake
# 31496   2014-04-19 13:28:00.810  ...  earthquake
# 33537   2014-04-13 12:36:19.230  ...  earthquake
# 95913   2014-10-14 03:51:34.460  ...  earthquake
# 31850   2014-04-18 14:27:24.920  ...  earthquake
# 34318   2014-04-11 07:07:23.130  ...  earthquake
# 106285  2014-11-15 02:31:41.720  ...  earthquake
# 111052  2014-11-01 18:57:22.380  ...  earthquake
# 97602   2014-10-09 02:14:31.440  ...  earthquake
# 47934   2014-06-29 07:52:55.170  ...  earthquake
# 78063   2014-08-03 00:22:03.680  ...  earthquake
# 50609   2014-06-23 19:19:15.940  ...  earthquake
# 14025   2014-02-12 09:19:49.060  ...  earthquake
# 61294   2014-07-21 14:54:41.000  ...  earthquake
# 37367   2014-04-01 23:57:58.790  ...  earthquake
# ...

# %% [markdown]
# ### Find the 10 states / countries with the highest number of earthquakes.

# %%
g[['place']]
# Out:
#                                           place
# 37371                 94km NW of Iquique, Chile
# 50562   19km SE of Little Sitkin Island, Alaska
# 36918                 53km SW of Iquique, Chile
# 33808     93km SSE of Kirakira, Solomon Islands
# 31496      70km SW of Panguna, Papua New Guinea
# 33537      112km S of Kirakira, Solomon Islands
# 95913           74km S of Intipuca, El Salvador
# 31850              33km ESE of Petatlan, Mexico
# 34318     56km WSW of Panguna, Papua New Guinea
# 106285      154km NW of Kota Ternate, Indonesia
# 111052            144km NE of Ndoi Island, Fiji
# 97602                Southern East Pacific Rise
# 47934             154km NNW of Visokoi Island,
# 78063     Federated States of Micronesia region
# 50609     80km SSE of Raoul Island, New Zealand
# 14025                 272km ESE of Hotan, China
# 61294             99km NNE of Ndoi Island, Fiji
# 37367                91km WNW of Iquique, Chile
# 39915          22km SSW of Kamariotissa, Greece
# ...

# %% [markdown]
# ### Find the top 10 states / countries where the strongest and weakest earthquakes occured.

# %%
t=c.nlargest(10, 'mag')
t
print('Top 10 states / countries where the strongest earthquakes occured:')
t[['place']]
# Out:
# Top 10 states / countries where the strongest earthquakes occured:
#                                           place
# 37371                 94km NW of Iquique, Chile
# 50562   19km SE of Little Sitkin Island, Alaska
# 36918                 53km SW of Iquique, Chile
# 33808     93km SSE of Kirakira, Solomon Islands
# 31496      70km SW of Panguna, Papua New Guinea
# 33537      112km S of Kirakira, Solomon Islands
# 95913           74km S of Intipuca, El Salvador
# 31850              33km ESE of Petatlan, Mexico
# 34318     56km WSW of Panguna, Papua New Guinea
# 106285      154km NW of Kota Ternate, Indonesia

# %%
s=c.nsmallest(10, 'mag')
s['place']
print('Top 10 states / countries where the weakest earthquakes occured:')
s[['place']]
# Out:
# Top 10 states / countries where the weakest earthquakes occured:
#                                   place
# 116943  16km SE of Three Rivers, Oregon
# 57895     38km NNE of Amboy, Washington
# 63534     38km NNE of Amboy, Washington
# 74269     38km NNE of Amboy, Washington
# 76157     38km NNE of Amboy, Washington
# 78794   16km SE of Three Rivers, Oregon
# 78893   16km SE of Three Rivers, Oregon
# 79181   16km SE of Three Rivers, Oregon
# 79362   16km SE of Three Rivers, Oregon
# 79627   16km SE of Three Rivers, Oregon

# %% [markdown]
# ### Q3 Matplotlib Assignment

# %% [markdown]
# ### Describe the data

# %%
df = pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Plot the frequency of the three species in the Iris Dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv("Iris.csv")
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot('Species',data=iris)
plt.title("Iris Species Count")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Plot the Pie of the three species in the Iris Dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv("Iris.csv")
ax=plt.subplots(1,1,figsize=(10,8))
iris['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.title("Iris Species %")
plt.show()

# %% [markdown]
# ### Combining Box and Strip Plots for Species vs sepal length.

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(x='Species',y='SepalLengthCm',data=iris)
fig=sns.stripplot(x='Species',y='SepalLengthCm',data=iris,jitter=True,edgecolor='gray')

# %% [markdown]
# ### Find out the correlation between different features in the dataset.

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',center=0)

# %%
sns.heatmap(df.select_dtypes(include='float'))

# %%
sns.pairplot(df,x_vars=['SepalLengthCm','SepalWidthCm'], 
             y_vars=['PetalLengthCm','PetalWidthCm'],hue='Species',palette='Set2')

# %% [markdown]
# ### Q4 Pandas+Matplotlib Assignment

# %% [markdown]
# ### Reading the dataset using read_csv()

# %%
import pandas as pd 
# create a Dataframe 
df = pd.read_csv("Indicators.csv") 
df
# Out:
#           CountryName CountryCode  ...    Year         Value
# 0          Arab World         ARB  ...  1960.0  1.335609e+02
# 1          Arab World         ARB  ...  1960.0  8.779760e+01
# 2          Arab World         ARB  ...  1960.0  6.634579e+00
# 3          Arab World         ARB  ...  1960.0  8.102333e+01
# 4          Arab World         ARB  ...  1960.0  3.000000e+06
# ...               ...         ...  ...     ...           ...
# 242949  Cote d'Ivoire         CIV  ...  1968.0  4.069987e+01
# 242950  Cote d'Ivoire         CIV  ...  1968.0  1.291000e+11
# 242951  Cote d'Ivoire         CIV  ...  1968.0  5.214798e+08
# 242952  Cote d'Ivoire         CIV  ...  1968.0  1.270491e+01
# 242953  Cote d'Ivoire         CIV  ...     NaN           NaN
#
# [242954 rows x 6 columns]

# %% [markdown]
# ### How many UNIQUE country names are there ?

# %%
unique_value = df["CountryName"].nunique() 
unique_value
# Out:
# 247

# %% [markdown]
# ###Are there the same number of country codes ?

# %%
boolean = not df["CountryCode"].is_unique      
boolean = df['CountryCode'].duplicated().any() 
boolean
#Returns True if there are  duplicates
# Out:
# True

# %% [markdown]
# ###Are there many indicators or few ?

# %%
print("Indicators")
for row in df['IndicatorName']:
  print(row)
print("\n")
indicators = df['IndicatorName'].unique().tolist()
print("Number of Indicators:",len(indicators))
# Out:
# Streaming output truncated to the last 5000 lines.
# Changes in inventories (current US$)
# Chemicals (% of value added in manufacturing)
# CO2 emissions (kg per 2005 US$ of GDP)
# CO2 emissions (kt)
# CO2 emissions (metric tons per capita)
# CO2 emissions from electricity and heat production, total (% of total fuel combustion)
# CO2 emissions from gaseous fuel consumption (% of total)
# CO2 emissions from gaseous fuel consumption (kt)
# CO2 emissions from liquid fuel consumption (% of total)
# CO2 emissions from liquid fuel consumption (kt)
# CO2 emissions from manufacturing industries and construction (% of total fuel combustion)
# CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)
# CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)
# CO2 emissions from solid fuel consumption (% of total)
# CO2 emissions from solid fuel consumption (kt)
# ...

# %% [markdown]
# ### How many years of data do we have ?

# %%
years = df['Year'].unique().tolist()
len(years)
# Out:
# 10

# %% [markdown]
# ### What's the range of years?

# %%
print(min(years)," to ",max(years))
# Out:
# 1960.0  to  1968.0

# %% [markdown]
# ### ScatterPlot for comparing GDP against CO2 emissions (per capita)

# %% [markdown]
# India

# %%
#collecting data for India 

first_indicator = 'CO2 emissions \(metric'
country = 'India'

mask1 = df['IndicatorName'].str.contains(first_indicator) 
mask2 = df['CountryName'].str.contains(country)  #Notice how we are using Country Name here, rather than the Country Code 

stage_India = df[mask1 & mask2]
# select GDP Per capita emissions for the India
second_indicator = 'GDP per capita \(constant 2005'
country = 'India'

mask1 = df['IndicatorName'].str.contains(second_indicator) 
mask2 = df['CountryName'].str.contains(country)

# stage is just those indicators matching the USA for country code and CO2 emissions over time.
gdp_stage_India = df[mask1 & mask2]
gdp_stage_trunc_India = gdp_stage_India[gdp_stage_India['Year'] < 2012]
# %matplotlib inline

#Plotting a subplot
fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.set_title('CO2 Emissions vs. GDP \(per capita\) for INDIA',fontsize=10)
axis.set_xlabel(gdp_stage_trunc_India['IndicatorName'].iloc[0],fontsize=10)   
axis.set_ylabel(stage_India['IndicatorName'].iloc[0],fontsize=10)

X = gdp_stage_trunc_India['Value']                   # Obtaining GDP values 
Y = stage_India['Value']                             # Obtaining CO2 values

axis.scatter(X, Y)
plt.show()

# %% [markdown]
# USA

# %%
first_indicator = 'CO2 emissions \(metric'
country = 'USA'

mask1 = df['IndicatorName'].str.contains(first_indicator) 
mask2 = df['CountryCode'].str.contains(country)

# stage is just those indicators matching the USA for country code and CO2 emissions over time.
stage_USA = df[mask1 & mask2]
# select GDP Per capita emissions for the United States
second_indicator = 'GDP per capita \(constant 2005'
country = 'USA'

mask1 = df['IndicatorName'].str.contains(second_indicator) 
mask2 = df['CountryCode'].str.contains(country)



# stage is just those indicators matching the USA for country code and CO2 emissions over time.
gdp_stage_USA = df[mask1 & mask2]
print(len(gdp_stage_USA))
gdp_stage_USA.head()
gdp_stage_trunc_USA = gdp_stage_USA[gdp_stage_USA['Year'] < 2012]
print(len(gdp_stage_trunc_USA))
# %matplotlib inline

#Plotting a subplot 
fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.set_title('CO2 Emissions vs. GDP (per capita) for USA',fontsize=10)
axis.set_xlabel(gdp_stage_trunc_USA['IndicatorName'].iloc[0],fontsize=10)   
axis.set_ylabel(stage_USA['IndicatorName'].iloc[0],fontsize=10)

X = gdp_stage_trunc_USA['Value']                   # Obtaining GDP values 
Y = stage_USA['Value']                             # Obtaining CO2 values

axis.scatter(X, Y)
plt.show()
# Out:
# 8
# 8
